# %%
import pandas as pd
import requests
from io import StringIO
import networkx as nx
import numpy as np

# %%
def load_csv_from_github(start_year, end_year):
    base_url = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_{}.csv"
    df_list = []

    for year in range(start_year, end_year + 1):
        url = base_url.format(year)
        response = requests.get(url)
        if response.status_code == 200:  # Check if the request was successful
            data = StringIO(response.text)
            df = pd.read_csv(data)
            df_list.append(df)
        else:
            print(f"Failed to retrieve data for year {year}")

    # Combine all DataFrames into a single DataFrame
    combined_df = pd.concat(df_list, ignore_index=True)
    return combined_df

# Load data from 2000 to 2024
atp_data = load_csv_from_github(1968, 2024)

# %%
atp_data.tail(10)
# Out:
#                               tourney_id                  tourney_name  \
# 194986  2024-M-DC-2024-WG2-PO-TUN-CRC-01  Davis Cup WG2 PO: TUN vs CRC
# 194987  2024-M-DC-2024-WG2-PO-TUN-CRC-01  Davis Cup WG2 PO: TUN vs CRC
# 194988  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA
# 194989  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA
# 194990  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA
# 194991  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA
# 194992  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
# 194993  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
# 194994  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
# 194995  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
#
#        surface  draw_size tourney_level  tourney_date  match_num  winner_id  \
# 194986    Hard        4.0             D      20240202          1     121411
# 194987    Hard        4.0             D      20240202          2     144826
# 194988    Clay        4.0             D      20240203          1     208364
# 194989    Clay        4.0             D      20240203          2     105430
# 194990    Clay        4.0             D      20240203          4     105430
# 194991    Clay        4.0             D      20240203          5     212051
# 194992    Hard        4.0             D      20240202          1     122533
# 194993    Hard        4.0             D      20240202          2     144748
# 194994    Hard        4.0             D      20240202          4     122533
# 194995    Hard        4.0             D      20240202          5     202475
#
#         winner_seed winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  \
# 194986          NaN          NaN  ...    30.0     17.0       9.0     8.0
# 194987          NaN          NaN  ...    51.0     36.0      15.0    15.0
# 194988          NaN          NaN  ...    52.0     24.0      18.0    12.0
# 194989          NaN          NaN  ...    31.0     13.0       6.0     8.0
# 194990          NaN          NaN  ...    66.0     33.0       6.0     8.0
# 194991          NaN          NaN  ...    30.0     17.0       7.0     6.0
# 194992          NaN          NaN  ...    41.0     25.0       6.0     9.0
# 194993          NaN          NaN  ...    51.0     25.0       7.0    11.0
# 194994          NaN          NaN  ...    51.0     32.0      17.0    14.0
# 194995          NaN          NaN  ...    53.0     25.0       8.0     8.0
#
#         l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 194986        2.0        5.0        279.0              205.0      900.0
# 194987        4.0        9.0        219.0              278.0        NaN
# 194988        8.0       16.0        616.0               55.0      740.0
# 194989        0.0        6.0        136.0              489.0     1109.0
# 194990        6.0       11.0        136.0              489.0      616.0
# 194991        8.0       14.0       1109.0                8.0      740.0
# 194992        1.0        4.0        554.0               67.0      748.0
# 194993        5.0       12.0        416.0              109.0        NaN
# 194994        5.0        9.0        554.0               67.0      416.0
# 194995        9.0       14.0        748.0               32.0        NaN
#
#        loser_rank_points
# 194986              18.0
# 194987               NaN
# 194988              34.0
# 194989               8.0
# 194990              55.0
# 194991              34.0
# 194992              32.0
# 194993               NaN
# 194994             109.0
# 194995               NaN
#
# [10 rows x 49 columns]

# %%
# Save the data
pickle_path = "/Users/saurabhkumar/Desktop/Work/Tennis"
# atp_data.to_pickle(f"{pickle_path}/ATPdata1968_2024.pkl")
# Read the data
atp_data = pd.read_pickle(f"{pickle_path}//ATPdata1968_2024.pkl")
